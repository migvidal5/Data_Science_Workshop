# %%
#import libraries to read, modify, and visualize data
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the data
df = pd.read_csv('/Users/miguelvidal/Downloads/public_sport_science_datasets-main/Oura Ring Data/oura_2019_trends.csv')

# Once the data is loaded, call the name of the dataframe to see what it looks like
df
# Out:
#            date  average_rhr  sleep_score  activity_score  readiness_score
# 0    2018-12-17          NaN          NaN            93.0              NaN
# 1    2018-12-18       59.750         84.0            99.0             93.0
# 2    2018-12-19       57.375         75.0            98.0             68.0
# 3    2018-12-20       52.625         82.0            98.0             87.0
# 4    2018-12-21       57.375         80.0            96.0             82.0
# ..          ...          ...          ...             ...              ...
# 295  2019-12-28       76.240         53.0            90.0             36.0
# 296  2019-12-29       64.040         80.0            91.0             80.0
# 297  2019-12-30       56.920         73.0            90.0             81.0
# 298  2019-12-31          NaN          NaN            78.0             87.0
# 299  2020-01-01       73.450         61.0            75.0             58.0
#
# [300 rows x 5 columns]

# %%
# .head() will show the first 5 rows in the dataframe

df.head()
# Out:
#          date  average_rhr  sleep_score  activity_score  readiness_score
# 0  2018-12-17          NaN          NaN            93.0              NaN
# 1  2018-12-18       59.750         84.0            99.0             93.0
# 2  2018-12-19       57.375         75.0            98.0             68.0
# 3  2018-12-20       52.625         82.0            98.0             87.0
# 4  2018-12-21       57.375         80.0            96.0             82.0

# %%
# .tail() will show the last 5 rows in the dataframe

df.tail()
# Out:
#            date  average_rhr  sleep_score  activity_score  readiness_score
# 295  2019-12-28        76.24         53.0            90.0             36.0
# 296  2019-12-29        64.04         80.0            91.0             80.0
# 297  2019-12-30        56.92         73.0            90.0             81.0
# 298  2019-12-31          NaN          NaN            78.0             87.0
# 299  2020-01-01        73.45         61.0            75.0             58.0

# %%
# Notice that there are NaN (Not a Number) values in the dataframe. Let's find out how many rows have NaN values.

# By using .isna() each value in the dataframe is tested to determine if it is a NaN value.
# The result is a boolean showing True or False results. True means the value is NaN.

df.isna()
# Out:
#       date  average_rhr  sleep_score  activity_score  readiness_score
# 0    False         True         True           False             True
# 1    False        False        False           False            False
# 2    False        False        False           False            False
# 3    False        False        False           False            False
# 4    False        False        False           False            False
# ..     ...          ...          ...             ...              ...
# 295  False        False        False           False            False
# 296  False        False        False           False            False
# 297  False        False        False           False            False
# 298  False         True         True           False            False
# 299  False        False        False           False            False
#
# [300 rows x 5 columns]

# %%
# Counting the number of True booleans would be tedious if done by hand.
# Luckily .sum() does the counting for us.

df.isna().sum()
# Out:
# date                0
# average_rhr        59
# sleep_score        59
# activity_score      4
# readiness_score    33
# dtype: int64

# %%
# Lets drop all rows with NaN values

df.dropna()
# Out:
#            date  average_rhr  sleep_score  activity_score  readiness_score
# 1    2018-12-18       59.750         84.0            99.0             93.0
# 2    2018-12-19       57.375         75.0            98.0             68.0
# 3    2018-12-20       52.625         82.0            98.0             87.0
# 4    2018-12-21       57.375         80.0            96.0             82.0
# 5    2018-12-22       55.500         91.0            93.0             87.0
# ..          ...          ...          ...             ...              ...
# 294  2019-12-27       64.670         76.0            97.0             82.0
# 295  2019-12-28       76.240         53.0            90.0             36.0
# 296  2019-12-29       64.040         80.0            91.0             80.0
# 297  2019-12-30       56.920         73.0            90.0             81.0
# 299  2020-01-01       73.450         61.0            75.0             58.0
#
# [238 rows x 5 columns]

# %%
# Lets make sure all NaN values have been dropped

df.isna().sum()
# Out:
# date                0
# average_rhr        59
# sleep_score        59
# activity_score      4
# readiness_score    33
# dtype: int64

# %%
# The reason the NaN values are still there is because the dataframe was never updated

# In order to update the dataframe the equal sign must be used.

df = df.dropna()

df.isna().sum()
# Out:
# date               0
# average_rhr        0
# sleep_score        0
# activity_score     0
# readiness_score    0
# dtype: int64

# %%
# Now lets see what each column looks like by using .describe()

df.describe()
# Out:
#        average_rhr  sleep_score  activity_score  readiness_score
# count   238.000000   238.000000      238.000000       238.000000
# mean     60.201786    77.945378       91.306723        78.210084
# std       8.068780     9.343941        7.475024        11.370162
# min      45.750000    46.000000       68.000000        36.000000
# 25%      54.500000    73.000000       89.000000        70.000000
# 50%      58.825000    80.000000       93.000000        80.000000
# 75%      64.562500    85.000000       97.000000        87.000000
# max      88.970000    98.000000      100.000000        96.000000

# %%
# Now lets visualize these results shown above with whisker plots

df.boxplot()
# Out:
# <AxesSubplot:>

# %%
fig1, ax1 = plt.subplots()
ax1.boxplot(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/xq/qpzp60ms2xd6d1ss5q8y9n_h0000gn/T/ipykernel_90318/868702391.py in <module>
#       1 fig1, ax1 = plt.subplots()
# ----> 2 ax1.boxplot(df)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
# Due to the error we got above lets check the types of data of each column

df.dtypes
# Out:
# date                object
# average_rhr        float64
# sleep_score        float64
# activity_score     float64
# readiness_score    float64
# dtype: object

# %%
# Notice that date is included and is an object. Matplotlib reads that column and spits out an error.
# Lets remove the date column and see if we get the same error

df_no_date = df[['average_rhr', 'sleep_score', 'activity_score', 'readiness_score']]

fig1, ax1 = plt.subplots()
ax1.boxplot(df_no_date)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc3bce95430>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fc3bce95af0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc3bce95100>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7fc3bce9e280>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc3bce9e610>,
# ...
#  'means': []}

# %%
# Another way to write the code
# Seaborn looks for numerical (Float64) columns, similar to the df.boxplot() example above
# Notice what dataframe is being used

sns.set_theme(style="whitegrid")
ax = sns.boxplot(data=df)
